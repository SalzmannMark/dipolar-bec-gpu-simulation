# %%
import sys
sys.path.append('/home/salzmann/Desktop/einc/cluster_home/ultracold-dipolar/Own_program_vault')
import main_version_2 as mv2
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors
from matplotlib import colors
import os
import gc

fontsize = 15
plt.rcParams["image.origin"] = 'lower'
plt.rcParams['legend.handlelength'] = 0.5


pgf_with_rc_fonts = {
    "font.family": "serif",
    "font.serif": [],
    "font.sans-serif": ["DejaVu Sans"]
}
plt.rcParams.update(pgf_with_rc_fonts)

plt.rc('font', **{'family': 'serif', 'serif': ['Computer Modern Roman'],
                  'size': fontsize})
plt.rc('text', usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{amsmath} \usepackage{amsfonts}')
plt.rc('legend', fontsize=fontsize,
       title_fontsize=fontsize)


# Get the current working directory (where the notebook is running)
current_directory = os.getcwd()

# %%
import re
ground_state_files = []
ground_state_paths = []
name_pattern = re.compile(r"ground_state_wave_function.vtk$")

for root, dirs, files in os.walk(current_directory, topdown=True):
    for filename in files:
        if name_pattern.match(filename):
            print(filename)
# Out:
# ground_state_wave_function.vtk
# ground_state_wave_function.vtk
# ground_state_wave_function.vtk
# ground_state_wave_function.vtk
# ground_state_wave_function.vtk

# %%
import re
ground_state_files = []
ground_state_paths = []
name_pattern = re.compile(r"ground_state_wave_function.vtk$")

for root, dirs, files in os.walk(current_directory, topdown=True):
    for filename in files:
        if name_pattern.match(filename):
            full_path = os.path.join(root, filename)
            ground_state_files.append(full_path)
            ground_state_paths.append(root)

ground_state_paths_sorted = sorted(ground_state_paths, key=lambda x: x[-29:])

ground_state_files_sorted = sorted(ground_state_files, key=lambda p: float(re.search(r"edd_([0-9.]+)", p).group(1)))

# %%
r_measure = 10.185
z_slice = 128

# %%
superfluid_ratios = []
edge_fraction = []
summed_up_number_of_particles = []
integrated_number_density = []
for i in range(len(ground_state_files_sorted)):
    print(i, ground_state_files_sorted[i])
    proc = mv2.TestProcessing.Three_D(file=ground_state_files_sorted[i], iteration=0)
    proc.print_out_stuff()
    realspace_density = proc.density_real_space()
    grid_spacing = proc.grid_spacing
    momentumspace_density = proc.density_momentum_space()

    proc.PLOT_Two_D_slice(r_input=r_measure, save=False, z_slice=z_slice)
    mask = proc.cylindrical_mask(center = None ,radius_1= 80, radius_2= 120) 
    mask = mask.astype(bool)  

    proc.PLOT_Two_D_slice(r_input=r_measure, save=False, z_slice=z_slice, radial_mask=mask)

    masked_density_full = np.where(mask[:, :, None], realspace_density, 0)
    masked_manifold = np.where(masked_density_full<10, 0.0,1.0)
    alpha = masked_manifold[:,:,z_slice]
    masked_volume=np.sum(masked_manifold)*grid_spacing[0]*grid_spacing[1]*grid_spacing[2]
    masked_number_of_particles=np.sum(masked_density_full)*grid_spacing[0]*grid_spacing[1]*grid_spacing[2]
    masked_number_density=masked_number_of_particles/masked_volume

    asdfa, full_vol_container = proc.Leggetts_integral(fxyz=masked_manifold, nr=512, ntheta=512, delta_z = grid_spacing[2], center=None, with_radial_profile=False)
    Legget_integral, integrated_number, radial_profile = proc.Leggetts_integral(fxyz=masked_density_full, nr=512, ntheta=512, delta_z = grid_spacing[2], center=None, with_radial_profile=True)

    integrated_density = integrated_number/full_vol_container


    Leggets_estimate = 1/(integrated_number*Legget_integral)

    print("integrated density: ", integrated_density)
    print("summed up density in the volume: ", masked_number_density)
    print("superfluid ratio according to Leggets estimate",Leggets_estimate*2*np.pi*2*np.pi)

    superfluid_ratios.append(Leggets_estimate*2*np.pi*2*np.pi)
    integrated_number_density.append(integrated_density)
    summed_up_number_of_particles.append(masked_number_of_particles)
    edge_fraction.append(masked_number_of_particles/proc.number_of_particles)
    plt.plot( np.linspace(0, 2*np.pi, radial_profile.shape[0]), radial_profile)
    plt.xlabel('Angle [rad]')
    plt.ylabel('Density')
    plt.title('Radial profile of the density')
# Out:
# 0 /home/salzmann/Desktop/einc/cluster_home/ultracold-dipolar/Static_groundstate_3/cylinder_hard_wall/N_100000_cutoff_0/r_10.185_edd_1.320/ground_state_wave_function.vtk
# initial_scattering_length = 100.0
# final_scattering_length = 132.0
# dipolar_length = 132.0
# number_of_particles = 100000
# atomic_mass = 164.0
# Particles after simulation:  100000.00022809567
# Number of density maxima: 25 (candidates before suppression: 25)
# initial healing length at maximal density:  0.21052833164251725
# initial healing length at minimal density:  3681734223.8445544
# final healing length at maximal density:  0.18324139242296583
# final healing length at minimal density:  3204538317.6936526
# Number of density maxima: 20 (candidates before suppression: 20)
# initial healing length at maximal density:  0.21052833164251725
# initial healing length at minimal density:  2189.5064481544314
# final healing length at maximal density:  0.18324139242296583
# final healing length at minimal density:  1905.7207509730454
# integrated density:  84.96888361528859
# summed up density in the volume:  84.20263241034321
# superfluid ratio according to Leggets estimate 1.003593229092737
# 1 /home/salzmann/Desktop/einc/cluster_home/ultracold-dipolar/Static_groundstate_3/cylinder_hard_wall/N_100000_cutoff_0/r_10.185_edd_1.404/ground_state_wave_function.vtk
# initial_scattering_length = 94.01709401709402
# final_scattering_length = 132.0
# dipolar_length = 132.0
# number_of_particles = 100000
# atomic_mass = 164.0
# Particles after simulation:  99999.9993935229
# Number of density maxima: 29 (candidates before suppression: 37)
# initial healing length at maximal density:  0.19660516708685224
# initial healing length at minimal density:  3985359964.3368425
# final healing length at maximal density:  0.16592482706743106
# final healing length at minimal density:  3363442439.902565
# Number of density maxima: 20 (candidates before suppression: 20)
# initial healing length at maximal density:  0.19660516708685224
# initial healing length at minimal density:  2371.674480399362
# final healing length at maximal density:  0.16592482706743106
# final healing length at minimal density:  2001.5734268401116
# integrated density:  93.64831863015895
# summed up density in the volume:  92.76191428190788
# superfluid ratio according to Leggets estimate 1.0031532387712194
# 2 /home/salzmann/Desktop/einc/cluster_home/ultracold-dipolar/Static_groundstate_3/cylinder_hard_wall/N_100000_cutoff_0/r_10.185_edd_1.410/ground_state_wave_function.vtk
# initial_scattering_length = 93.61702127659575
# final_scattering_length = 132.0
# dipolar_length = 132.0
# number_of_particles = 100000
# atomic_mass = 164.0
# Particles after simulation:  100000.00040840305
# Number of density maxima: 25 (candidates before suppression: 35)
# initial healing length at maximal density:  0.19066284203265774
# initial healing length at minimal density:  3997748054.67985
# final healing length at maximal density:  0.16056707869380496
# final healing length at minimal density:  3366711204.1885753
# Number of density maxima: 16 (candidates before suppression: 18)
# initial healing length at maximal density:  0.19066284203265774
# initial healing length at minimal density:  2392.9150495822914
# final healing length at maximal density:  0.16056707869380496
# final healing length at minimal density:  2015.198005954711
# integrated density:  94.50360069441983
# summed up density in the volume:  93.60894236372233
# superfluid ratio according to Leggets estimate 1.0014434924130085
# 3 /home/salzmann/Desktop/einc/cluster_home/ultracold-dipolar/Static_groundstate_3/cylinder_hard_wall/N_100000_cutoff_0/r_10.185_edd_1.425/ground_state_wave_function.vtk
# initial_scattering_length = 92.63157894736841
# final_scattering_length = 132.0
# dipolar_length = 132.0
# number_of_particles = 100000
# atomic_mass = 164.0
# Particles after simulation:  100000.00008888537
# Number of density maxima: 21 (candidates before suppression: 25)
# initial healing length at maximal density:  0.11539854616189027
# initial healing length at minimal density:  10372080158.76557
# final healing length at maximal density:  0.09667026414217475
# final healing length at minimal density:  8688772623.227417
# Number of density maxima: 16 (candidates before suppression: 16)
# initial healing length at maximal density:  0.11539854616189027
# initial healing length at minimal density:  4246.708854020291
# final healing length at maximal density:  0.09667026414217475
# final healing length at minimal density:  3557.5012017666927
# integrated density:  111.5208626771948
# summed up density in the volume:  110.95071063541029
# superfluid ratio according to Leggets estimate 0.5133525089722398
# 4 /home/salzmann/Desktop/einc/cluster_home/ultracold-dipolar/Static_groundstate_3/cylinder_hard_wall/N_100000_cutoff_0/r_10.185_edd_1.467/ground_state_wave_function.vtk
# initial_scattering_length = 89.97955010224949
# final_scattering_length = 132.0
# dipolar_length = 132.0
# number_of_particles = 100000
# atomic_mass = 164.0
# Particles after simulation:  99999.99875654637
# Number of density maxima: 13 (candidates before suppression: 13)
# initial healing length at maximal density:  0.07858374056017667
# initial healing length at minimal density:  9284984485.265244
# final healing length at maximal density:  0.06488101573980011
# final healing length at minimal density:  7665952527.04957
# Number of density maxima: 13 (candidates before suppression: 13)
# initial healing length at maximal density:  0.07858374056017667
# initial healing length at minimal density:  26031.18658141825
# final healing length at maximal density:  0.06488101573980011
# final healing length at minimal density:  21492.10274638617
# /home/salzmann/Desktop/einc/cluster_home/ultracold-dipolar/Own_program_vault/main_version_2.py:918: RuntimeWarning: divide by zero encountered in divide
#   legget_integral = integrate.trapezoid(1 / radial_integral, x=theta)
# integrated density:  204.47438133545967
# summed up density in the volume:  204.50204168079014
# superfluid ratio according to Leggets estimate 0.06477404750540978

# %%
edd_values = [float(re.search(r"edd_([0-9.]+)", path).group(1)) for path in ground_state_files_sorted]

# %%
edd_values
# Out:
# [1.32, 1.404, 1.41, 1.425, 1.467]

# %%
edge_fraction
# Out:
# [np.float64(0.4530249764599269),
#  np.float64(0.5041950347057284),
#  np.float64(0.5087609201512355),
#  np.float64(0.5726671966537157),
#  np.float64(0.7158785422511302)]

# %%
import csv

# Pair edd values with corresponding superfluid_ratios
results = list(zip(edd_values, superfluid_ratios, edge_fraction))

# Save the results to a CSV file
with open("data_N_100k_mit_cutoff.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(["edd_value", "superfluid_ratio"])
    writer.writerows(results)
